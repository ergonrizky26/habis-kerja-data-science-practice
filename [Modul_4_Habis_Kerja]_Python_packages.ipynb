# %% [markdown]
# <a href="https://colab.research.google.com/github/ergonrizky26/habis-kerja-data-science-practice/blob/DS001/%5BModul_4_Habis_Kerja%5D_Python_packages.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 1. Pandas and NumPy

# %%
# Import pandas library
import pandas as pd

# %%
# Membuat DataFrame
df = pd.DataFrame(columns=['Nama','Mafa'])

# %%
df
# Out:
# Empty DataFrame
# Columns: [Nama, Mafa]
# Index: []

# %%
# Memasukkan data
df = df.append({'Nama':'Mike','Mafa':'Nasgor'}, ignore_index=True)
df = df.append({'Nama':'Ben','Mafa':'Mie Instant'}, ignore_index=True)
df['Mifa'] = ['Kopi','Es teh']
df
# Out:
# <ipython-input-5-834395ab8279>:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Nama':'Mike','Mafa':'Nasgor'}, ignore_index=True)
# <ipython-input-5-834395ab8279>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Nama':'Ben','Mafa':'Mie Instant'}, ignore_index=True)
#    Nama         Mafa    Mifa
# 0  Mike       Nasgor    Kopi
# 1   Ben  Mie Instant  Es teh
